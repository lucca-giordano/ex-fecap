# %%
import requests
url='https://www.uol.com.br'

dados = requests.get(url)
print(dados.status_code)
dados.content
# Out:
# The kernel failed to start as a dll could not be loaded.
#
# Click <a href='https://aka.ms/kernelFailuresDllLoad'>here</a> for more info.

# %%
import requests
url='https://bloomberg-market-and-financial-news.p.rapidapi.com/market/get-movers'
dados = requests.get(url,params= {"id": 'nky:ind', "template": 'INDEX'}, headers= {
    'X-RapidAPI-Key': '7395c74fcdmshc55eca2cd2c9a8cp1901a1jsn9d93900b7993',
    'X-RapidAPI-Host': 'bloomberg-market-and-financial-news.p.rapidapi.com'
  })
dados.content
# Out:
# b'{"active":[{"securityType":"Common Stock","symbol":"9432","exchange":"Tokyo","country":"Japan","currency":"JPY","resourceType":"Company","fundamentalDataCurrency":"JPY","resourceSubtype":"Public","region":"APAC","ticker":"9432:jp","tickerName":"9432:JP","template":"Stock","tinyName":"Nippon Telegraph & Telephone Corp","name":"Nippon Telegraph & Telephone Corp","watchlist":true,"resourceId":"9432:JP","last":"149","netChange":"-1","lastPriceTime":1726200000,"pctChange1M":"-1","yearHigh":"193","dayHigh":"151","volume":1.758624E+8,"yearLow":"142","dayLow":"149","pctChangeYTD":"-14","pctChange":"-0.80"},{"securityType":"Common Stock","symbol":"7011","exchange":"Tokyo","country":"Japan","currency":"JPY","resourceType":"Company","fundamentalDataCurrency":"JPY","resourceSubtype":"Public","region":"APAC","ticker":"7011:jp","tickerName":"7011:JP","template":"Stock","tinyName":"Mitsubishi Heavy Industries Ltd","name":"Mitsubishi Heavy Industries Ltd","watchlist":true,"resourceId":"7011:JP","last":"1774","netChange":"41","lastPriceTime":1726200000,"pctChange1M":"-8","yearHigh":"2095","dayHigh":"1784","volume":5.50757E+7,"yearLow":"733","dayLow":"1725","pctChangeYTD":"115","pctChange":"2.37"},{"securityType":"Common Stock","symbol":"8306","exchange":"Tokyo","country":"Japan","currency":"JPY","resourceType":"Company","fundamentalDataCurrency":"JPY","resourceSubtype":"Public","region":"APAC","ticker":"8306:jp","tickerName":"8306:JP","template":"Stock","tinyName":"Mitsubishi UFJ Financial Group Inc","name":"Mitsubishi UFJ Financial Group Inc","watchlist":true,"resourceId":"8306:JP","last":"1451","netChange":"-8","lastPriceTime":1726200000,"pctChange1M":"-7","yearHigh":"1850","dayHigh":"1462","volume":5.26356E+7,"yearLow":"1164","dayLow":"1443","pctChangeYTD":"20","pctChange":"-0.55"},{"securityType":"Common Stock","symbol":"7203","exchange":"Tokyo","country":"Japan","currency":"JPY","resourceType":"Company","fundamentalDataCurrency":"JPY","resourceSubtype":"Public","region":"APAC","ticker":"7203:jp","tickerName":"7203:JP","template":"Stock","tinyName":"Toyota Motor Corp","name":"Toyota Motor Corp","watchlist":true,"resourceId":"7203:JP","last":"2455","netChange":"-58","lastPriceTime":1726200000,"pctChange1M":"-11","yearHigh":"3891","dayHigh":"2498","volume":3.30031E+7,"yearLow":"2183","dayLow":"2446","pctChangeYTD":"-5","pctChange":"-2.31"},{"securityType":"Common Stock","symbol":"4755","exchange":"Tokyo","country":"Japan","currency":"JPY","resourceType":"Company","fundamentalDataCurrency":"JPY","resourceSubtype":"Public","region":"APAC","ticker":"4755:jp","tickerName":"4755:JP","template":"Stock","tinyName":"Rakuten Group Inc","name":"Rakuten Group Inc","watchlist":true,"resourceId":"4755:JP","last":"947","netChange":"9","lastPriceTime":1726200000,"pctChange1M":"6","yearHigh":"1070","dayHigh":"959","volume":2.61544E+7,"yearLow":"531","dayLow":"931","pctChangeYTD":"51","pctChange":"0.93"},{"securityType":"Common Stock","symbol":"7201","exchange":"Tokyo","country":"Japan","currency":"JPY","resourceType":"Company","fundamentalDataCurrency":"JPY","resourceSubtype":"Public","region":"APAC","ticker":"7201:jp","tickerName":"7201:JP","template":"Stock","tinyName":"Nissan Motor Co Ltd","name":"Nissan Motor Co Ltd","watchlist":true,"resourceId":"7201:JP","last":"391","netChange":"-3","lastPriceTime":1726200000,"pctChange1M":"-12","yearHigh":"712","dayHigh":"395","volume":2.00013E+7,"yearLow":"377","dayLow":"390","pctChangeYTD":"-29","pctChange":"-0.79"},{"securityType":"Common Stock","symbol":"9501","exchange":"Tokyo","country":"Japan","currency":"JPY","resourceType":"Company","fundamentalDataCurrency":"JPY","resourceSubtype":"Public","region":"APAC","ticker":"9501:jp","tickerName":"9501:JP","template":"Stock","tinyName":"Tokyo Electric Power Co Holdings Inc","name":"Tokyo Electric Power Co Holdings Inc","watchlist":true,"resourceId":"9501:JP","last":"638","netChange":"-6","lastPriceTime":1726200000,"pctChange1M":"-8","yearHigh":"1114","dayHigh":"64 ...

# %%
print(dados.json())
# Out:
# {'active': [{'securityType': 'Common Stock', 'symbol': '9432', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '9432:jp', 'tickerName': '9432:JP', 'template': 'Stock', 'tinyName': 'Nippon Telegraph & Telephone Corp', 'name': 'Nippon Telegraph & Telephone Corp', 'watchlist': True, 'resourceId': '9432:JP', 'last': '149', 'netChange': '-1', 'lastPriceTime': 1726200000, 'pctChange1M': '-1', 'yearHigh': '193', 'dayHigh': '151', 'volume': 175862400.0, 'yearLow': '142', 'dayLow': '149', 'pctChangeYTD': '-14', 'pctChange': '-0.80'}, {'securityType': 'Common Stock', 'symbol': '7011', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '7011:jp', 'tickerName': '7011:JP', 'template': 'Stock', 'tinyName': 'Mitsubishi Heavy Industries Ltd', 'name': 'Mitsubishi Heavy Industries Ltd', 'watchlist': True, 'resourceId': '7011:JP', 'last': '1774', 'netChange': '41', 'lastPriceTime': 1726200000, 'pctChange1M': '-8', 'yearHigh': '2095', 'dayHigh': '1784', 'volume': 55075700.0, 'yearLow': '733', 'dayLow': '1725', 'pctChangeYTD': '115', 'pctChange': '2.37'}, {'securityType': 'Common Stock', 'symbol': '8306', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '8306:jp', 'tickerName': '8306:JP', 'template': 'Stock', 'tinyName': 'Mitsubishi UFJ Financial Group Inc', 'name': 'Mitsubishi UFJ Financial Group Inc', 'watchlist': True, 'resourceId': '8306:JP', 'last': '1451', 'netChange': '-8', 'lastPriceTime': 1726200000, 'pctChange1M': '-7', 'yearHigh': '1850', 'dayHigh': '1462', 'volume': 52635600.0, 'yearLow': '1164', 'dayLow': '1443', 'pctChangeYTD': '20', 'pctChange': '-0.55'}, {'securityType': 'Common Stock', 'symbol': '7203', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '7203:jp', 'tickerName': '7203:JP', 'template': 'Stock', 'tinyName': 'Toyota Motor Corp', 'name': 'Toyota Motor Corp', 'watchlist': True, 'resourceId': '7203:JP', 'last': '2455', 'netChange': '-58', 'lastPriceTime': 1726200000, 'pctChange1M': '-11', 'yearHigh': '3891', 'dayHigh': '2498', 'volume': 33003100.0, 'yearLow': '2183', 'dayLow': '2446', 'pctChangeYTD': '-5', 'pctChange': '-2.31'}, {'securityType': 'Common Stock', 'symbol': '4755', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '4755:jp', 'tickerName': '4755:JP', 'template': 'Stock', 'tinyName': 'Rakuten Group Inc', 'name': 'Rakuten Group Inc', 'watchlist': True, 'resourceId': '4755:JP', 'last': '947', 'netChange': '9', 'lastPriceTime': 1726200000, 'pctChange1M': '6', 'yearHigh': '1070', 'dayHigh': '959', 'volume': 26154400.0, 'yearLow': '531', 'dayLow': '931', 'pctChangeYTD': '51', 'pctChange': '0.93'}, {'securityType': 'Common Stock', 'symbol': '7201', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '7201:jp', 'tickerName': '7201:JP', 'template': 'Stock', 'tinyName': 'Nissan Motor Co Ltd', 'name': 'Nissan Motor Co Ltd', 'watchlist': True, 'resourceId': '7201:JP', 'last': '391', 'netChange': '-3', 'lastPriceTime': 1726200000, 'pctChange1M': '-12', 'yearHigh': '712', 'dayHigh': '395', 'volume': 20001300.0, 'yearLow': '377', 'dayLow': '390', 'pctChangeYTD': '-29', 'pctChange': '-0.79'}, {'securityType': 'Common Stock', 'symbol': '9501', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceS ...

# %%
import json
dados_dict=json.loads(dados.content)
dados_dict.keys()
# Out:
# dict_keys(['active', 'laggards', 'leaders'])

# %%
print("ACTIVE:",dados_dict["active"])
print("LAGGARDS:",dados_dict["laggards"])
print("LEADERS:",dados_dict["leaders"])
# Out:
# ACTIVE: [{'securityType': 'Common Stock', 'symbol': '9432', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '9432:jp', 'tickerName': '9432:JP', 'template': 'Stock', 'tinyName': 'Nippon Telegraph & Telephone Corp', 'name': 'Nippon Telegraph & Telephone Corp', 'watchlist': True, 'resourceId': '9432:JP', 'last': '149', 'netChange': '-1', 'lastPriceTime': 1726200000, 'pctChange1M': '-1', 'yearHigh': '193', 'dayHigh': '151', 'volume': 175862400.0, 'yearLow': '142', 'dayLow': '149', 'pctChangeYTD': '-14', 'pctChange': '-0.80'}, {'securityType': 'Common Stock', 'symbol': '7011', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '7011:jp', 'tickerName': '7011:JP', 'template': 'Stock', 'tinyName': 'Mitsubishi Heavy Industries Ltd', 'name': 'Mitsubishi Heavy Industries Ltd', 'watchlist': True, 'resourceId': '7011:JP', 'last': '1774', 'netChange': '41', 'lastPriceTime': 1726200000, 'pctChange1M': '-8', 'yearHigh': '2095', 'dayHigh': '1784', 'volume': 55075700.0, 'yearLow': '733', 'dayLow': '1725', 'pctChangeYTD': '115', 'pctChange': '2.37'}, {'securityType': 'Common Stock', 'symbol': '8306', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '8306:jp', 'tickerName': '8306:JP', 'template': 'Stock', 'tinyName': 'Mitsubishi UFJ Financial Group Inc', 'name': 'Mitsubishi UFJ Financial Group Inc', 'watchlist': True, 'resourceId': '8306:JP', 'last': '1451', 'netChange': '-8', 'lastPriceTime': 1726200000, 'pctChange1M': '-7', 'yearHigh': '1850', 'dayHigh': '1462', 'volume': 52635600.0, 'yearLow': '1164', 'dayLow': '1443', 'pctChangeYTD': '20', 'pctChange': '-0.55'}, {'securityType': 'Common Stock', 'symbol': '7203', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '7203:jp', 'tickerName': '7203:JP', 'template': 'Stock', 'tinyName': 'Toyota Motor Corp', 'name': 'Toyota Motor Corp', 'watchlist': True, 'resourceId': '7203:JP', 'last': '2455', 'netChange': '-58', 'lastPriceTime': 1726200000, 'pctChange1M': '-11', 'yearHigh': '3891', 'dayHigh': '2498', 'volume': 33003100.0, 'yearLow': '2183', 'dayLow': '2446', 'pctChangeYTD': '-5', 'pctChange': '-2.31'}, {'securityType': 'Common Stock', 'symbol': '4755', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '4755:jp', 'tickerName': '4755:JP', 'template': 'Stock', 'tinyName': 'Rakuten Group Inc', 'name': 'Rakuten Group Inc', 'watchlist': True, 'resourceId': '4755:JP', 'last': '947', 'netChange': '9', 'lastPriceTime': 1726200000, 'pctChange1M': '6', 'yearHigh': '1070', 'dayHigh': '959', 'volume': 26154400.0, 'yearLow': '531', 'dayLow': '931', 'pctChangeYTD': '51', 'pctChange': '0.93'}, {'securityType': 'Common Stock', 'symbol': '7201', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '7201:jp', 'tickerName': '7201:JP', 'template': 'Stock', 'tinyName': 'Nissan Motor Co Ltd', 'name': 'Nissan Motor Co Ltd', 'watchlist': True, 'resourceId': '7201:JP', 'last': '391', 'netChange': '-3', 'lastPriceTime': 1726200000, 'pctChange1M': '-12', 'yearHigh': '712', 'dayHigh': '395', 'volume': 20001300.0, 'yearLow': '377', 'dayLow': '390', 'pctChangeYTD': '-29', 'pctChange': '-0.79'}, {'securityType': 'Common Stock', 'symbol': '9501', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubt ...
# LAGGARDS: [{'securityType': 'Common Stock', 'symbol': '4503', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '4503:jp', 'tickerName': '4503:JP', 'template': 'Stock', 'tinyName': 'Astellas Pharma Inc', 'name': 'Astellas Pharma Inc', 'watchlist': True, 'resourceId': '4503:JP', 'last': '1705', 'netChange': '-84', 'lastPriceTime': 1726200000, 'pctChange1M': '-1', 'yearHigh': '2222', 'dayHigh': '1805', 'volume': 11212800.0, 'yearLow': '1426', 'dayLow': '1698', 'pctChangeYTD': '1', 'pctChange': '-4.72'}, {'securityType': 'Common Stock', 'symbol': '9766', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '9766:jp', 'tickerName': '9766:JP', 'template': 'Stock', 'tinyName': 'Konami Group Corp', 'name': 'Konami Group Corp', 'watchlist': True, 'resourceId': '9766:JP', 'last': '13550', 'netChange': '-535', 'lastPriceTime': 1726200000, 'pctChange1M': '14', 'yearHigh': '14145', 'dayHigh': '14070', 'volume': 811400.0, 'yearLow': '7068', 'dayLow': '13455', 'pctChangeYTD': '84', 'pctChange': '-3.80'}, {'securityType': 'Common Stock', 'symbol': '2802', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '2802:jp', 'tickerName': '2802:JP', 'template': 'Stock', 'tinyName': 'Ajinomoto Co Inc', 'name': 'Ajinomoto Co Inc', 'watchlist': True, 'resourceId': '2802:JP', 'last': '5285', 'netChange': '-198', 'lastPriceTime': 1726200000, 'pctChange1M': '-4', 'yearHigh': '6390', 'dayHigh': '5428', 'volume': 2623400.0, 'yearLow': '4886', 'dayLow': '5241', 'pctChangeYTD': '-3', 'pctChange': '-3.61'}, {'securityType': 'Common Stock', 'symbol': '4507', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '4507:jp', 'tickerName': '4507:JP', 'template': 'Stock', 'tinyName': 'Shionogi & Co Ltd', 'name': 'Shionogi & Co Ltd', 'watchlist': True, 'resourceId': '4507:JP', 'last': '6311', 'netChange': '-223', 'lastPriceTime': 1726200000, 'pctChange1M': '-3', 'yearHigh': '8137', 'dayHigh': '6504', 'volume': 1403000.0, 'yearLow': '5834', 'dayLow': '6286', 'pctChangeYTD': '-7', 'pctChange': '-3.41'}, {'securityType': 'Common Stock', 'symbol': '4751', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '4751:jp', 'tickerName': '4751:JP', 'template': 'Stock', 'tinyName': 'CyberAgent Inc', 'name': 'CyberAgent Inc', 'watchlist': True, 'resourceId': '4751:JP', 'last': '1024', 'netChange': '-34', 'lastPriceTime': 1726200000, 'pctChange1M': '7', 'yearHigh': '1136', 'dayHigh': '1056', 'volume': 3853300.0, 'yearLow': '756', 'dayLow': '1018', 'pctChangeYTD': '16', 'pctChange': '-3.26'}, {'securityType': 'Common Stock', 'symbol': '7751', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '7751:jp', 'tickerName': '7751:JP', 'template': 'Stock', 'tinyName': 'Canon Inc', 'name': 'Canon Inc', 'watchlist': True, 'resourceId': '7751:JP', 'last': '4719', 'netChange': '-158', 'lastPriceTime': 1726200000, 'pctChange1M': '-0', 'yearHigh': '5121', 'dayHigh': '4870', 'volume': 5645000.0, 'yearLow': '3422', 'dayLow': '4708', 'pctChangeYTD': '30', 'pctChange': '-3.24'}, {'securityType': 'Common Stock', 'symbol': '3659', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '3659:jp', 'tickerName': '3659:JP', 'template': 'Stock' ...
# LEADERS: [{'securityType': 'Common Stock', 'symbol': '7012', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '7012:jp', 'tickerName': '7012:JP', 'template': 'Stock', 'tinyName': 'Kawasaki Heavy Industries Ltd', 'name': 'Kawasaki Heavy Industries Ltd', 'watchlist': True, 'resourceId': '7012:JP', 'last': '4918', 'netChange': '333', 'lastPriceTime': 1726200000, 'pctChange1M': '-3', 'yearHigh': '6719', 'dayHigh': '4970', 'volume': 12732300.0, 'yearLow': '2786', 'dayLow': '4673', 'pctChangeYTD': '58', 'pctChange': '7.26'}, {'securityType': 'Common Stock', 'symbol': '3405', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '3405:jp', 'tickerName': '3405:JP', 'template': 'Stock', 'tinyName': 'Kuraray Co Ltd', 'name': 'Kuraray Co Ltd', 'watchlist': True, 'resourceId': '3405:JP', 'last': '1955', 'netChange': '78', 'lastPriceTime': 1726200000, 'pctChange1M': '3', 'yearHigh': '1997', 'dayHigh': '1997', 'volume': 4043000.0, 'yearLow': '1387', 'dayLow': '1894', 'pctChangeYTD': '37', 'pctChange': '4.18'}, {'securityType': 'Common Stock', 'symbol': '4911', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '4911:jp', 'tickerName': '4911:JP', 'template': 'Stock', 'tinyName': 'Shiseido Co Ltd', 'name': 'Shiseido Co Ltd', 'watchlist': True, 'resourceId': '4911:JP', 'last': '3345', 'netChange': '133', 'lastPriceTime': 1726200000, 'pctChange1M': '-5', 'yearHigh': '5724', 'dayHigh': '3353', 'volume': 4804500.0, 'yearLow': '3055', 'dayLow': '3221', 'pctChangeYTD': '-21', 'pctChange': '4.14'}, {'securityType': 'Common Stock', 'symbol': '6361', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '6361:jp', 'tickerName': '6361:JP', 'template': 'Stock', 'tinyName': 'Ebara Corp', 'name': 'Ebara Corp', 'watchlist': True, 'resourceId': '6361:JP', 'last': '1980', 'netChange': '78', 'lastPriceTime': 1726200000, 'pctChange1M': '-5', 'yearHigh': '2859', 'dayHigh': '1993', 'volume': 5903400.0, 'yearLow': '1263', 'dayLow': '1904', 'pctChangeYTD': '19', 'pctChange': '4.07'}, {'securityType': 'Common Stock', 'symbol': '3099', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '3099:jp', 'tickerName': '3099:JP', 'template': 'Stock', 'tinyName': 'Isetan Mitsukoshi Holdings Ltd', 'name': 'Isetan Mitsukoshi Holdings Ltd', 'watchlist': True, 'resourceId': '3099:JP', 'last': '2263', 'netChange': '84', 'lastPriceTime': 1726200000, 'pctChange1M': '-11', 'yearHigh': '3674', 'dayHigh': '2314', 'volume': 5700700.0, 'yearLow': '1486', 'dayLow': '2200', 'pctChangeYTD': '48', 'pctChange': '3.83'}, {'securityType': 'Common Stock', 'symbol': '8253', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '8253:jp', 'tickerName': '8253:JP', 'template': 'Stock', 'tinyName': 'Credit Saison Co Ltd', 'name': 'Credit Saison Co Ltd', 'watchlist': True, 'resourceId': '8253:JP', 'last': '3489', 'netChange': '82', 'lastPriceTime': 1726200000, 'pctChange1M': '7', 'yearHigh': '3566', 'dayHigh': '3513', 'volume': 1286200.0, 'yearLow': '2120', 'dayLow': '3382', 'pctChangeYTD': '35', 'pctChange': '2.41'}, {'securityType': 'Common Stock', 'symbol': '7011', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '7011:jp', 'ticker ...

# %%
import pandas as pd
df_active=pd.DataFrame(dados_dict["active"])
df_active
# Out:
#    securityType symbol exchange country currency resourceType  \
# 0  Common Stock   9432    Tokyo   Japan      JPY      Company
# 1  Common Stock   7011    Tokyo   Japan      JPY      Company
# 2  Common Stock   8306    Tokyo   Japan      JPY      Company
# 3  Common Stock   7203    Tokyo   Japan      JPY      Company
# 4  Common Stock   4755    Tokyo   Japan      JPY      Company
# 5  Common Stock   7201    Tokyo   Japan      JPY      Company
# 6  Common Stock   9501    Tokyo   Japan      JPY      Company
# 7  Common Stock   4385    Tokyo   Japan      JPY      Company
# 8  Common Stock   7267    Tokyo   Japan      JPY      Company
# 9  Common Stock   6857    Tokyo   Japan      JPY      Company
#
#   fundamentalDataCurrency resourceSubtype region   ticker  ... netChange  \
# 0                     JPY          Public   APAC  9432:jp  ...        -1
# 1                     JPY          Public   APAC  7011:jp  ...        41
# 2                     JPY          Public   APAC  8306:jp  ...        -8
# 3                     JPY          Public   APAC  7203:jp  ...       -58
# 4                     JPY          Public   APAC  4755:jp  ...         9
# 5                     JPY          Public   APAC  7201:jp  ...        -3
# 6                     JPY          Public   APAC  9501:jp  ...        -6
# 7                     JPY          Public   APAC  4385:jp  ...       -18
# 8                     JPY          Public   APAC  7267:jp  ...       -22
# 9                     JPY          Public   APAC  6857:jp  ...        82
#
#   lastPriceTime pctChange1M yearHigh  dayHigh       volume yearLow dayLow  \
# 0    1726200000          -1      193      151  175862400.0     142    149
# 1    1726200000          -8     2095     1784   55075700.0     733   1725
# 2    1726200000          -7     1850     1462   52635600.0    1164   1443
# 3    1726200000         -11     3891     2498   33003100.0    2183   2446
# 4    1726200000           6     1070      959   26154400.0     531    931
# 5    1726200000         -12      712      395   20001300.0     377    390
# 6    1726200000          -8     1114      645   18750000.0     575    634
# 7    1726200000          15     3446     2510   16921200.0    1700   2382
# 8    1726200000          -7     1960     1498   16136200.0    1239   1470
# 9    1726200000          -4     7456     6419   15269000.0    3500   6281
#
#    pctChangeYTD pctChange
# 0           -14     -0.80
# 1           115      2.37
# 2            20     -0.55
# 3            -5     -2.31
# 4            51      0.93
# 5           -29     -0.79
# 6           -14     -0.85
# 7            -8     -0.77
# 8             0     -1.44
# 9            33      1.30
#
# [10 rows x 27 columns]

# %%
from numpy.lib.function_base import append
float(df_active.pctChange[0])
pctChangeFloat=[]
for i in range(len(df_active.pctChange)):
  pctChangeFloat.append(float(df_active.pctChange[i]))

df_active["pct"]=pctChangeFloat
df_active["pct"]
# Out:
# 0   -0.80
# 1    2.37
# 2   -0.55
# 3   -2.31
# 4    0.93
# 5   -0.79
# 6   -0.85
# 7   -0.77
# 8   -1.44
# 9    1.30
# Name: pct, dtype: float64

# %%
import matplotlib.pyplot as plt
eixoX=df_active["symbol"]
eixoY=df_active["pct"]
plt.figure(figsize=(7,5))
plt.bar(eixoX,eixoY)
plt.show()

# %%
import requests
url='https://bb-finance.p.rapidapi.com/market/get-cross-currencies'
dados = requests.get(url,params= {"id": 'brl,cad,eur,usd'}, headers= {
    'X-RapidAPI-Key': '7395c74fcdmshc55eca2cd2c9a8cp1901a1jsn9d93900b7993',
     'X-RapidAPI-Host': 'bb-finance.p.rapidapi.com'
  })
dados.content
# Out:
# b'{"result":{"USDEUR:cur":{"baseName":"EURO","securityType":"CROSS","symbol":"USDEUR","country":"Europe","currency":"EUR","resourceType":"Currency","resourceSubtype":"Cross","region":"EMEA","ticker":"usdeur:cur","tickerName":"USDEUR:CUR","template":"Currency","tinyName":"USD-EUR","name":"USDEUR Spot Exchange Rate - Price of 1 USD in EUR","watchlist":true,"resourceId":"USDEUR:CUR","last":"0.8986","netChange":"-0.0043","lastPriceTime":1726516365,"yearHigh":"0.9571","dayHigh":"0.9030","yearLow":"0.8927","sourceCurrency":"USD","dayLow":"0.8979","pctChange":"-0.48"},"EURUSD:cur":{"baseName":"US DOLLAR","securityType":"CROSS","symbol":"EURUSD","country":"United States","currency":"USD","resourceType":"Currency","resourceSubtype":"Cross","region":"AMERICAS","ticker":"eurusd:cur","tickerName":"EURUSD:CUR","template":"Currency","tinyName":"EUR-USD","name":"EURUSD Spot Exchange Rate - Price of 1 EUR in USD","watchlist":true,"resourceId":"EURUSD:CUR","last":"1.1128","netChange":"0.0053","lastPriceTime":1726516372,"yearHigh":"1.1202","dayHigh":"1.1138","volume":2147483648,"yearLow":"1.0448","sourceCurrency":"EUR","dayLow":"1.1074","pctChange":"0.48"},"USDCAD:cur":{"baseName":"CANADIAN DOLLAR","securityType":"CROSS","symbol":"USDCAD","country":"Canada","currency":"CAD","resourceType":"Currency","resourceSubtype":"Cross","region":"AMERICAS","ticker":"usdcad:cur","tickerName":"USDCAD:CUR","template":"Currency","tinyName":"USD-CAD","name":"USDCAD Spot Exchange Rate - Price of 1 USD in CAD","watchlist":true,"resourceId":"USDCAD:CUR","last":"1.3586","netChange":"0.0001","lastPriceTime":1726516674,"yearHigh":"1.3946","dayHigh":"1.3608","volume":2147483648,"yearLow":"1.3177","sourceCurrency":"USD","dayLow":"1.3567","pctChange":"0.01"},"CADUSD:cur":{"baseName":"US DOLLAR","securityType":"CROSS","symbol":"CADUSD","country":"United States","currency":"USD","resourceType":"Currency","resourceSubtype":"Cross","region":"AMERICAS","ticker":"cadusd:cur","tickerName":"CADUSD:CUR","template":"Currency","tinyName":"CAD-USD","name":"CADUSD Spot Exchange Rate - Price of 1 CAD in USD","watchlist":true,"resourceId":"CADUSD:CUR","last":"0.7361","netChange":"0.0000","lastPriceTime":1726516687,"yearHigh":"0.7589","dayHigh":"0.7371","volume":2147483648,"yearLow":"0.7170","sourceCurrency":"CAD","dayLow":"0.7349","pctChange":"0.00"},"USDBRL:cur":{"baseName":"BRAZIL REAL","securityType":"CROSS","symbol":"USDBRL","country":"Brazil","currency":"BRL","resourceType":"Currency","resourceSubtype":"Cross","region":"AMERICAS","ticker":"usdbrl:cur","tickerName":"USDBRL:CUR","template":"Currency","tinyName":"USD-BRL","name":"USDBRL Spot Exchange Rate - Price of 1 USD in BRL","watchlist":true,"resourceId":"USDBRL:CUR","last":"5.5108","netChange":"-0.0551","lastPriceTime":1726516684,"yearHigh":"5.8588","dayHigh":"5.5802","yearLow":"4.8039","sourceCurrency":"USD","dayLow":"5.4980","pctChange":"-0.99"},"BRLUSD:cur":{"baseName":"US DOLLAR","securityType":"CROSS","symbol":"BRLUSD","country":"United States","currency":"USD","resourceType":"Currency","resourceSubtype":"Cross","region":"AMERICAS","ticker":"brlusd:cur","tickerName":"BRLUSD:CUR","template":"Currency","tinyName":"BRL-USD","name":"BRLUSD Spot Exchange Rate - Price of 1 BRL in USD","watchlist":true,"resourceId":"BRLUSD:CUR","last":"0.1815","netChange":"0.0018","lastPriceTime":1726516684,"yearHigh":"0.2082","dayHigh":"0.1819","yearLow":"0.1707","sourceCurrency":"BRL","dayLow":"0.1792","pctChange":"1.00"},"EURCAD:cur":{"baseName":"CANADIAN DOLLAR","securityType":"CROSS","symbol":"EURCAD","country":"Canada","currency":"CAD","resourceType":"Currency","resourceSubtype":"Cross","region":"AMERICAS","ticker":"eurcad:cur","tickerName":"EURCAD:CUR","template":"Currency","tinyName":"EUR-CAD","name":"EURCAD Spot Exchange Rate - Price of 1 EUR in CAD","watchlist":true,"resourceId":"EURCAD:CUR","last":"1.51153","netChange":"0.00705","lastPriceTime":1726515090,"yearHigh":"1.52278","dayHigh":"1.51323","volume":1073741824,"yearLow":"1.41579" ...

# %%
import json
dados_dict=json.loads(dados.content)
dados_dict.keys()
# Out:
# dict_keys(['result'])

# %%
print(dados_dict["result"])
# Out:
# {'USDEUR:cur': {'baseName': 'EURO', 'securityType': 'CROSS', 'symbol': 'USDEUR', 'country': 'Europe', 'currency': 'EUR', 'resourceType': 'Currency', 'resourceSubtype': 'Cross', 'region': 'EMEA', 'ticker': 'usdeur:cur', 'tickerName': 'USDEUR:CUR', 'template': 'Currency', 'tinyName': 'USD-EUR', 'name': 'USDEUR Spot Exchange Rate - Price of 1 USD in EUR', 'watchlist': True, 'resourceId': 'USDEUR:CUR', 'last': '0.8986', 'netChange': '-0.0043', 'lastPriceTime': 1726516365, 'yearHigh': '0.9571', 'dayHigh': '0.9030', 'yearLow': '0.8927', 'sourceCurrency': 'USD', 'dayLow': '0.8979', 'pctChange': '-0.48'}, 'EURUSD:cur': {'baseName': 'US DOLLAR', 'securityType': 'CROSS', 'symbol': 'EURUSD', 'country': 'United States', 'currency': 'USD', 'resourceType': 'Currency', 'resourceSubtype': 'Cross', 'region': 'AMERICAS', 'ticker': 'eurusd:cur', 'tickerName': 'EURUSD:CUR', 'template': 'Currency', 'tinyName': 'EUR-USD', 'name': 'EURUSD Spot Exchange Rate - Price of 1 EUR in USD', 'watchlist': True, 'resourceId': 'EURUSD:CUR', 'last': '1.1128', 'netChange': '0.0053', 'lastPriceTime': 1726516372, 'yearHigh': '1.1202', 'dayHigh': '1.1138', 'volume': 2147483648, 'yearLow': '1.0448', 'sourceCurrency': 'EUR', 'dayLow': '1.1074', 'pctChange': '0.48'}, 'USDCAD:cur': {'baseName': 'CANADIAN DOLLAR', 'securityType': 'CROSS', 'symbol': 'USDCAD', 'country': 'Canada', 'currency': 'CAD', 'resourceType': 'Currency', 'resourceSubtype': 'Cross', 'region': 'AMERICAS', 'ticker': 'usdcad:cur', 'tickerName': 'USDCAD:CUR', 'template': 'Currency', 'tinyName': 'USD-CAD', 'name': 'USDCAD Spot Exchange Rate - Price of 1 USD in CAD', 'watchlist': True, 'resourceId': 'USDCAD:CUR', 'last': '1.3586', 'netChange': '0.0001', 'lastPriceTime': 1726516674, 'yearHigh': '1.3946', 'dayHigh': '1.3608', 'volume': 2147483648, 'yearLow': '1.3177', 'sourceCurrency': 'USD', 'dayLow': '1.3567', 'pctChange': '0.01'}, 'CADUSD:cur': {'baseName': 'US DOLLAR', 'securityType': 'CROSS', 'symbol': 'CADUSD', 'country': 'United States', 'currency': 'USD', 'resourceType': 'Currency', 'resourceSubtype': 'Cross', 'region': 'AMERICAS', 'ticker': 'cadusd:cur', 'tickerName': 'CADUSD:CUR', 'template': 'Currency', 'tinyName': 'CAD-USD', 'name': 'CADUSD Spot Exchange Rate - Price of 1 CAD in USD', 'watchlist': True, 'resourceId': 'CADUSD:CUR', 'last': '0.7361', 'netChange': '0.0000', 'lastPriceTime': 1726516687, 'yearHigh': '0.7589', 'dayHigh': '0.7371', 'volume': 2147483648, 'yearLow': '0.7170', 'sourceCurrency': 'CAD', 'dayLow': '0.7349', 'pctChange': '0.00'}, 'USDBRL:cur': {'baseName': 'BRAZIL REAL', 'securityType': 'CROSS', 'symbol': 'USDBRL', 'country': 'Brazil', 'currency': 'BRL', 'resourceType': 'Currency', 'resourceSubtype': 'Cross', 'region': 'AMERICAS', 'ticker': 'usdbrl:cur', 'tickerName': 'USDBRL:CUR', 'template': 'Currency', 'tinyName': 'USD-BRL', 'name': 'USDBRL Spot Exchange Rate - Price of 1 USD in BRL', 'watchlist': True, 'resourceId': 'USDBRL:CUR', 'last': '5.5108', 'netChange': '-0.0551', 'lastPriceTime': 1726516684, 'yearHigh': '5.8588', 'dayHigh': '5.5802', 'yearLow': '4.8039', 'sourceCurrency': 'USD', 'dayLow': '5.4980', 'pctChange': '-0.99'}, 'BRLUSD:cur': {'baseName': 'US DOLLAR', 'securityType': 'CROSS', 'symbol': 'BRLUSD', 'country': 'United States', 'currency': 'USD', 'resourceType': 'Currency', 'resourceSubtype': 'Cross', 'region': 'AMERICAS', 'ticker': 'brlusd:cur', 'tickerName': 'BRLUSD:CUR', 'template': 'Currency', 'tinyName': 'BRL-USD', 'name': 'BRLUSD Spot Exchange Rate - Price of 1 BRL in USD', 'watchlist': True, 'resourceId': 'BRLUSD:CUR', 'last': '0.1815', 'netChange': '0.0018', 'lastPriceTime': 1726516684, 'yearHigh': '0.2082', 'dayHigh': '0.1819', 'yearLow': '0.1707', 'sourceCurrency': 'BRL', 'dayLow': '0.1792', 'pctChange': '1.00'}, 'EURCAD:cur': {'baseName': 'CANADIAN DOLLAR', 'securityType': 'CROSS', 'symbol': 'EURCAD', 'country': 'Canada', 'currency': 'CAD', 'resourceType': 'Currency', 'resourceSubtype': 'Cross', 'region': 'AMERICAS', 'ticker': 'eurcad:cur', 'tickerNam ...

# %%
import pandas as pd
df_curr=pd.DataFrame(dados_dict["result"])
print(df_curr.keys())
df_curr
# Out:
# Index(['USDEUR:cur', 'EURUSD:cur', 'USDCAD:cur', 'CADUSD:cur', 'USDBRL:cur',
#        'BRLUSD:cur', 'EURCAD:cur', 'CADEUR:cur', 'EURBRL:cur', 'BRLEUR:cur',
#        'BRLCAD:cur'],
#       dtype='object')
#                                                         USDEUR:cur  \
# baseName                                                      EURO
# securityType                                                 CROSS
# symbol                                                      USDEUR
# country                                                     Europe
# currency                                                       EUR
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                        EMEA
# ticker                                                  usdeur:cur
# tickerName                                              USDEUR:CUR
# template                                                  Currency
# tinyName                                                   USD-EUR
# name             USDEUR Spot Exchange Rate - Price of 1 USD in EUR
# watchlist                                                     True
# resourceId                                              USDEUR:CUR
# last                                                        0.8986
# netChange                                                  -0.0043
# lastPriceTime                                           1726516365
# yearHigh                                                    0.9571
# dayHigh                                                     0.9030
# yearLow                                                     0.8927
# sourceCurrency                                                 USD
# dayLow                                                      0.8979
# pctChange                                                    -0.48
# volume                                                         NaN
#
#                                                         EURUSD:cur  \
# baseName                                                 US DOLLAR
# securityType                                                 CROSS
# symbol                                                      EURUSD
# country                                              United States
# currency                                                       USD
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  eurusd:cur
# tickerName                                              EURUSD:CUR
# template                                                  Currency
# tinyName                                                   EUR-USD
# name             EURUSD Spot Exchange Rate - Price of 1 EUR in USD
# watchlist                                                     True
# resourceId                                              EURUSD:CUR
# last                                                        1.1128
# netChange                                                   0.0053
# lastPriceTime                                           1726516372
# yearHigh                                                    1.1202
# dayHigh                                                     1.1138
# yearLow                                                     1.0448
# sourceCurrency                                                 EUR
# dayLow                                                      1.1074
# pctChange                                                     0.48
# volume                                                  2147483648
#
#                                                         USDCAD:cur  \
# baseName                                           CANADIAN DOLLAR
# securityType                                                 CROSS
# symbol                                                      USDCAD
# country                                                     Canada
# currency                                                       CAD
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  usdcad:cur
# tickerName                                              USDCAD:CUR
# template                                                  Currency
# tinyName                                                   USD-CAD
# name             USDCAD Spot Exchange Rate - Price of 1 USD in CAD
# watchlist                                                     True
# resourceId                                              USDCAD:CUR
# last                                                        1.3586
# netChange                                                   0.0001
# lastPriceTime                                           1726516674
# yearHigh                                                    1.3946
# dayHigh                                                     1.3608
# yearLow                                                     1.3177
# sourceCurrency                                                 USD
# dayLow                                                      1.3567
# pctChange                                                     0.01
# volume                                                  2147483648
#
#                                                         CADUSD:cur  \
# baseName                                                 US DOLLAR
# securityType                                                 CROSS
# symbol                                                      CADUSD
# country                                              United States
# currency                                                       USD
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  cadusd:cur
# tickerName                                              CADUSD:CUR
# template                                                  Currency
# tinyName                                                   CAD-USD
# name             CADUSD Spot Exchange Rate - Price of 1 CAD in USD
# watchlist                                                     True
# resourceId                                              CADUSD:CUR
# last                                                        0.7361
# netChange                                                   0.0000
# lastPriceTime                                           1726516687
# yearHigh                                                    0.7589
# dayHigh                                                     0.7371
# yearLow                                                     0.7170
# sourceCurrency                                                 CAD
# dayLow                                                      0.7349
# pctChange                                                     0.00
# volume                                                  2147483648
#
#                                                         USDBRL:cur  \
# baseName                                               BRAZIL REAL
# securityType                                                 CROSS
# symbol                                                      USDBRL
# country                                                     Brazil
# currency                                                       BRL
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  usdbrl:cur
# tickerName                                              USDBRL:CUR
# template                                                  Currency
# tinyName                                                   USD-BRL
# name             USDBRL Spot Exchange Rate - Price of 1 USD in BRL
# watchlist                                                     True
# resourceId                                              USDBRL:CUR
# last                                                        5.5108
# netChange                                                  -0.0551
# lastPriceTime                                           1726516684
# yearHigh                                                    5.8588
# dayHigh                                                     5.5802
# yearLow                                                     4.8039
# sourceCurrency                                                 USD
# dayLow                                                      5.4980
# pctChange                                                    -0.99
# volume                                                         NaN
#
#                                                         BRLUSD:cur  \
# baseName                                                 US DOLLAR
# securityType                                                 CROSS
# symbol                                                      BRLUSD
# country                                              United States
# currency                                                       USD
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  brlusd:cur
# tickerName                                              BRLUSD:CUR
# template                                                  Currency
# tinyName                                                   BRL-USD
# name             BRLUSD Spot Exchange Rate - Price of 1 BRL in USD
# watchlist                                                     True
# resourceId                                              BRLUSD:CUR
# last                                                        0.1815
# netChange                                                   0.0018
# lastPriceTime                                           1726516684
# yearHigh                                                    0.2082
# dayHigh                                                     0.1819
# yearLow                                                     0.1707
# sourceCurrency                                                 BRL
# dayLow                                                      0.1792
# pctChange                                                     1.00
# volume                                                         NaN
#
#                                                         EURCAD:cur  \
# baseName                                           CANADIAN DOLLAR
# securityType                                                 CROSS
# symbol                                                      EURCAD
# country                                                     Canada
# currency                                                       CAD
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  eurcad:cur
# tickerName                                              EURCAD:CUR
# template                                                  Currency
# tinyName                                                   EUR-CAD
# name             EURCAD Spot Exchange Rate - Price of 1 EUR in CAD
# watchlist                                                     True
# resourceId                                              EURCAD:CUR
# last                                                       1.51153
# netChange                                                  0.00705
# lastPriceTime                                           1726515090
# yearHigh                                                   1.52278
# dayHigh                                                    1.51323
# yearLow                                                    1.41579
# sourceCurrency                                                 EUR
# dayLow                                                     1.50495
# pctChange                                                     0.47
# volume                                                  1073741824
#
#                                                         CADEUR:cur  \
# baseName                                                      EURO
# securityType                                                 CROSS
# symbol                                                      CADEUR
# country                                                     Europe
# currency                                                       EUR
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                        EMEA
# ticker                                                  cadeur:cur
# tickerName                                              CADEUR:CUR
# template                                                  Currency
# tinyName                                                   CAD-EUR
# name             CADEUR Spot Exchange Rate - Price of 1 CAD in EUR
# watchlist                                                     True
# resourceId                                              CADEUR:CUR
# last                                                        0.6616
# netChange                                                  -0.0030
# lastPriceTime                                           1726515054
# yearHigh                                                    0.7063
# dayHigh                                                     0.6647
# yearLow                                                     0.6567
# sourceCurrency                                                 CAD
# dayLow                                                      0.6608
# pctChange                                                    -0.45
# volume                                                         NaN
#
#                                                         EURBRL:cur  \
# baseName                                               BRAZIL REAL
# securityType                                                 CROSS
# symbol                                                      EURBRL
# country                                                     Brazil
# currency                                                       BRL
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  eurbrl:cur
# tickerName                                              EURBRL:CUR
# template                                                  Currency
# tinyName                                                   EUR-BRL
# name             EURBRL Spot Exchange Rate - Price of 1 EUR in BRL
# watchlist                                                     True
# resourceId                                              EURBRL:CUR
# last                                                        6.1328
# netChange                                                  -0.0313
# lastPriceTime                                           1726515074
# yearHigh                                                    6.4145
# dayHigh                                                     6.2067
# yearLow                                                     5.1704
# sourceCurrency                                                 EUR
# dayLow                                                      6.1185
# pctChange                                                    -0.51
# volume                                                         NaN
#
#                                                         BRLEUR:cur  \
# baseName                                                      EURO
# securityType                                                 CROSS
# symbol                                                      BRLEUR
# country                                                     Europe
# currency                                                       EUR
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                        EMEA
# ticker                                                  brleur:cur
# tickerName                                              BRLEUR:CUR
# template                                                  Currency
# tinyName                                                   BRL-EUR
# name             BRLEUR Spot Exchange Rate - Price of 1 BRL in EUR
# watchlist                                                     True
# resourceId                                              BRLEUR:CUR
# last                                                       0.16305
# netChange                                                  0.00084
# lastPriceTime                                           1726515024
# yearHigh                                                   0.19336
# dayHigh                                                    0.16344
# yearLow                                                    0.15837
# sourceCurrency                                                 BRL
# dayLow                                                     0.16113
# pctChange                                                     0.52
# volume                                                         NaN
#
#                                                         BRLCAD:cur
# baseName                                           CANADIAN DOLLAR
# securityType                                                 CROSS
# symbol                                                      BRLCAD
# country                                                     Canada
# currency                                                       CAD
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  brlcad:cur
# tickerName                                              BRLCAD:CUR
# template                                                  Currency
# tinyName                                                   BRL-CAD
# name             BRLCAD Spot Exchange Rate - Price of 1 BRL in CAD
# watchlist                                                     True
# resourceId                                              BRLCAD:CUR
# last                                                        0.2465
# netChange                                                   0.0024
# lastPriceTime                                           1726515024
# yearHigh                                                    0.2841
# dayHigh                                                     0.2472
# yearLow                                                     0.2372
# sourceCurrency                                                 BRL
# dayLow                                                      0.2434
# pctChange                                                     0.98
# volume                                                         NaN

# %%
import pandas as pd
df_curr=pd.DataFrame(dados_dict["result"])
df_curr.keys()
float(df_curr["USDEUR:cur"]["last"])
for x in df_curr.keys():
  print(x,":",float(df_curr[x]["last"]))
vlr=[]
for x in df_curr.keys():
  vlr.append(float(df_curr[x]["last"]))
vlr
# Out:
# USDEUR:cur : 0.8986
# EURUSD:cur : 1.1128
# USDCAD:cur : 1.3586
# CADUSD:cur : 0.7361
# USDBRL:cur : 5.5108
# BRLUSD:cur : 0.1815
# EURCAD:cur : 1.51153
# CADEUR:cur : 0.6616
# EURBRL:cur : 6.1328
# BRLEUR:cur : 0.16305
# BRLCAD:cur : 0.2465
# [0.8986,
#  1.1128,
#  1.3586,
#  0.7361,
#  5.5108,
#  0.1815,
#  1.51153,
#  0.6616,
#  6.1328,
#  0.16305,
#  0.2465]

# %%
import matplotlib.pyplot as plt
eixoX=df_curr.keys()
eixoY=vlr
plt.figure(figsize=(14,8))
plt.bar(eixoX,eixoY)
plt.show()
